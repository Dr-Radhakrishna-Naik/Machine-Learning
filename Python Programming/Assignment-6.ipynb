# %% [raw]
# 1.	For the dataset “Indian_cities”,
# a)	Find out top 10 states in female-male sex ratio
# b)	Find out top 10 cities in total number of graduates
# c)	Find out top 10 cities and their locations in respect of  total effective_literacy_rate.

# %%
import pandas as pd

# %%
data=pd.read_csv("C:/360DG/Datasets/Indian_cities.csv")

# %%
data
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
df1=data[['state_code','sex_ratio']]

# %%
df1
# Out:
#      state_code  sex_ratio
# 0             3        890
# 1            27        928
# 2            28        982
# 3            20        902
# 4            28       1013
# ..          ...        ...
# 488          28       1039
# 489          28        998
# 490          27        982
# 491           6        877
# 492          27        988
#
# [493 rows x 2 columns]

# %%
df=pd.DataFrame(df1)

# %%
df
# Out:
#      state_code  sex_ratio
# 0             3        890
# 1            27        928
# 2            28        982
# 3            20        902
# 4            28       1013
# ..          ...        ...
# 488          28       1039
# 489          28        998
# 490          27        982
# 491           6        877
# 492          27        988
#
# [493 rows x 2 columns]

# %%
df_final=df.sort_values(by=['state_code'])

# %%
df_final=df_final.sort_values(by=['sex_ratio'],ascending=False)

# %%
df_final.head(10)
# Out:
#      state_code  sex_ratio
# 278          32       1093
# 275          32       1077
# 461          32       1076
# 14           32       1076
# 459          32       1064
# 220          14       1055
# 358          32       1053
# 245          28       1046
# 378          34       1045
# 430          17       1042

# %%
df2=data[['name_of_city','total_graduates']]

# %%
df3=pd.DataFrame(df2)

# %%
df3
# Out:
#       name_of_city  total_graduates
# 0          Abohar             16287
# 1        Achalpur              8863
# 2        Adilabad             10565
# 3       Adityapur             19225
# 4           Adoni             11902
# ..             ...              ...
# 488  Vizianagaram             30656
# 489      Warangal            109613
# 490        Wardha             19363
# 491   Yamunanagar             29803
# 492      Yavatmal             13511
#
# [493 rows x 2 columns]

# %%
df_final2=df3.sort_values(by=['total_graduates'],ascending=False)

# %%
df_final2.head(10)
# Out:
#            name_of_city  total_graduates
# 141              Delhi           2221137
# 185     Greater Mumbai           1802371
# 72            Bengaluru          1591163
# 184  Greater Hyderabad           1164149
# 119            Chennai            879695
# 274            Kolkata            818476
# 7            Ahmadabad            769858
# 380               Pune            656508
# 288            Lucknow            596990
# 225             Jaipur            533148

# %%
df2=data[['name_of_city','location','effective_literacy_rate_total']]

# %%
df2
# Out:
#       name_of_city               location  effective_literacy_rate_total
# 0          Abohar   30.1452928,74.1993043                          79.86
# 1        Achalpur    21.257584,77.5086754                          91.99
# 2        Adilabad    19.0809075,79.560344                          80.51
# 3       Adityapur   22.7834741,86.1576889                          83.46
# 4           Adoni   15.6322227,77.2728368                          68.38
# ..             ...                    ...                            ...
# 488  Vizianagaram   18.1066576,83.3955506                          81.85
# 489      Warangal   17.9689008,79.5940544                          84.16
# 490        Wardha    20.745319,78.6021946                          94.05
# 491   Yamunanagar   30.1290485,77.2673901                          85.91
# 492      Yavatmal   20.3887937,78.1204073                          91.81
#
# [493 rows x 3 columns]

# %%
df3=pd.DataFrame(df2)

# %%
df3
# Out:
#       name_of_city               location  effective_literacy_rate_total
# 0          Abohar   30.1452928,74.1993043                          79.86
# 1        Achalpur    21.257584,77.5086754                          91.99
# 2        Adilabad    19.0809075,79.560344                          80.51
# 3       Adityapur   22.7834741,86.1576889                          83.46
# 4           Adoni   15.6322227,77.2728368                          68.38
# ..             ...                    ...                            ...
# 488  Vizianagaram   18.1066576,83.3955506                          81.85
# 489      Warangal   17.9689008,79.5940544                          84.16
# 490        Wardha    20.745319,78.6021946                          94.05
# 491   Yamunanagar   30.1290485,77.2673901                          85.91
# 492      Yavatmal   20.3887937,78.1204073                          91.81
#
# [493 rows x 3 columns]

# %%
df_final=df3.sort_values(by=['effective_literacy_rate_total'],ascending=False)

# %%
df_final
# Out:
#     name_of_city               location  effective_literacy_rate_total
# 9        Aizawl    23.727107,92.7176389                          98.80
# 271       Kochi    9.9312328,76.2673041                          97.49
# 461    Thrissur   10.5276416,76.2144349                          97.24
# 278   Kozhikode     11.2587531,75.78041                          96.80
# 14    Alappuzha    9.4980667,76.3388484                          96.56
# ..           ...                    ...                            ...
# 27       Amroha   28.9043537,78.4673426                          63.88
# 6          Agra   27.1766701,78.0080745                          63.44
# 396      Rampur   25.4842209,82.5916032                          60.74
# 39       Bagaha   27.1221959,84.0722375                          60.67
# 416     Sambhal   28.5903614,78.5717631                          49.51
#
# [493 rows x 3 columns]

# %%
df_final.head(10)
# Out:
#           name_of_city               location  effective_literacy_rate_total
# 9              Aizawl    23.727107,92.7176389                          98.80
# 271             Kochi    9.9312328,76.2673041                          97.49
# 461          Thrissur   10.5276416,76.2144349                          97.24
# 278         Kozhikode     11.2587531,75.78041                          96.80
# 14          Alappuzha    9.4980667,76.3388484                          96.56
# 264          Khardaha   22.7002943,88.3753455                          95.50
# 333         Nagercoil    8.1832857,77.4118996                          95.35
# 13            Alandur   12.9974873,80.2006371                          95.15
# 352  North Barrackpur    22.7902358,88.367179                          94.78
# 431            Shimla   31.1048145,77.1734033                          94.67

# %% [raw]
# 2.	For the data set “Indian_cities”
# a)	Construct histogram on literates_total and comment about the inferences
# b)	Construct scatter  plot between  male graduates and female graduates

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("c:/360DG/Datasets/Indian_cities.csv")

# %%
plt.hist(data.literates_total)
# Out:
# (array([471.,  10.,   4.,   3.,   2.,   0.,   1.,   0.,   1.,   1.]),
#  array([   56998. ,  1075056.8,  2093115.6,  3111174.4,  4129233.2,
#          5147292. ,  6165350.8,  7183409.6,  8201468.4,  9219527.2,
#         10237586. ]),
#  <a list of 10 Patch objects>)

# %% [raw]
# skewed right and it has outliers

# %%
import seaborn as sns
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.lmplot(x='male_graduates', y='female_graduates', data=data)

# %% [raw]
# 3.	For the data set “Indian_cities”
# a)	Construct Boxplot on total effective literacy rate and draw inferences
# b)	Find out the number of null values in each column of the dataset and delete them.

# %%
plt.boxplot(data.effective_literacy_rate_total)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b6db74b88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19b6db79b48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19b6db74208>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b6db7fac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b6db7fbc8>],
#  'means': []}

# %% [raw]
# There are several ouliers on right side

# %%
data.isna().sum()
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64
